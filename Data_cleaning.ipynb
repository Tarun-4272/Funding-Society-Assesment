# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('flats.csv')
df.sample(5)
# Out:
#                          property_name  \
# 1413   2 BHK Flat in Sector 86 Gurgaon
# 1229  3 BHK Flat in Sector 106 Gurgaon
# 2548   3 BHK Flat in Sector 59 Gurgaon
# 394    3 BHK Flat in Sector 86 Gurgaon
# 968   2 BHK Flat in Sector 106 Gurgaon
#
#                                                    link  \
# 1413  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 1229  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2548  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 394   https://www.99acres.com/3-bhk-bedroom-apartmen...
# 968   https://www.99acres.com/2-bhk-bedroom-apartmen...
#
#                       society       price             area  \
# 1413  Microtek Greenburg3.8 ★  1.23 Crore   ₹ 8,310/sq.ft.
# 1229               Paras Dews   1.2 Crore   ₹ 6,818/sq.ft.
# 2548        Conscient Elevate  4.25 Crore  ₹ 18,518/sq.ft.
# 394          DLF The Skycourt  1.56 Crore   ₹ 8,087/sq.ft.
# 968                Paras Dews      88 Lac   ₹ 6,353/sq.ft.
#
# ...

# %%
# shape
df.shape
# Out:
# (3017, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3017 entries, 0 to 3016
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3017 non-null   object
#  1   link             3017 non-null   object
#  2   society          3016 non-null   object
#  3   price            3007 non-null   object
#  4   area             3004 non-null   object
#  5   areaWithType     3008 non-null   object
#  6   bedRoom          3008 non-null   object
#  7   bathroom         3008 non-null   object
#  8   balcony          3008 non-null   object
#  9   additionalRoom   1694 non-null   object
#  10  address          3002 non-null   object
#  11  floorNum         3006 non-null   object
#  12  facing           2127 non-null   object
#  13  agePossession    3007 non-null   object
#  14  nearbyLocations  2913 non-null   object
#  15  description      3008 non-null   object
# ...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check for missing values
df.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                10
# area                 13
# areaWithType          9
# bedRoom               9
# bathroom              9
# balcony               9
# additionalRoom     1323
# address              15
# floorNum             11
# facing              890
# agePossession        10
# nearbyLocations     104
# description           9
# furnishDetails      814
# features            423
# rating              341
# property_id           9
# dtype: int64

# %%
# Columns to drop -> property_name, link, property_id
df.drop(columns=['link','property_id'], inplace=True)

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# rename columns
df.rename(columns={'area':'price_per_sqft'},inplace=True)
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# society
df['society'].value_counts()
# Out:
# SS The Leaf3.8 ★                                     73
# Tulip Violet4.3 ★                                    40
# Shapoorji Pallonji Joyville Gurugram4.0 ★            39
# Signature Global Park4.0 ★                           36
# Shree Vardhman Victoria3.8 ★                         35
# Tulip Violet4.2 ★                                    33
# Emaar MGF Emerald Floors Premier3.8 ★                32
# Smart World Gems                                     32
# Smart World Orchard                                  32
# DLF The Ultima4.0 ★                                  31
# Paras Dews                                           31
# DLF Regal Gardens3.9 ★                               30
# M3M Woodshire4.0 ★                                   29
# Shree Vardhman Flora3.8 ★                            29
# La Vida by Tata Housing                              28
# Signature Global Solera3.7 ★                         28
# Godrej Nature Plus                                   27
# ...

# %%
df['society'].value_counts().shape
# Out:
# (638,)

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].value_counts().shape
# Out:
# (604,)

# %%
df['society'].value_counts()
# Out:
# tulip violet                                     75
# ss the leaf                                      74
# shapoorji pallonji joyville gurugram             45
# dlf new town heights                             38
# signature global park                            36
# shree vardhman victoria                          35
# smart world gems                                 32
# emaar mgf emerald floors premier                 32
# smart world orchard                              32
# paras dews                                       31
# dlf the ultima                                   31
# dlf regal gardens                                30
# m3m woodshire                                    30
# shree vardhman flora                             29
# signature global solera                          28
# la vida by tata housing                          28
# godrej nature plus                               27
# bptp terra                                       25
# ...

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# price
df['price'].value_counts()
# Out:
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.2 Crore           59
# 1.5 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.9 Crore           40
# 1.55 Crore          40
# 1.65 Crore          38
# 75 Lac              38
# 1.7 Crore           37
# 1.8 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 1.15 Crore          33
# 50 Lac              33
# 1.45 Crore          31
# 85 Lac              31
# 1.05 Crore          30
# 2.5 Crore           29
# 60 Lac              29
# 40 Lac              29
# 2.1 Crore           26
# 45 Lac              26
# 65 Lac              25
# 35 Lac              23
# 2.35 Crore          23
# 1.85 Crore          23
# 3 Crore             22
# 70 Lac              21
# 55 Lac              20
# 2.25 Crore          20
# 3.5 Crore           19
# ...

# %%
df[df['price'] == 'Price on Request']
# Out:
#                          property_name                    society  \
# 25      5 BHK Flat in Sector 1 Gurgaon  the new people apartments
# 1644   4 BHK Flat in Sector 50 Gurgaon                ss hibiscus
# 1972   1 BHK Flat in Sector 31 Gurgaon            raheja atlantis
# 2054   2 BHK Flat in Sector 79 Gurgaon         supertech araville
# 2357  2 BHK Flat in Sector 37D Gurgaon            the millennia 2
# 2522  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2549      3 BHK Flat in Sector-2 Sohna         supertech hilltown
# 2640  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2959  3 BHK Flat in Sector 104 Gurgaon              godrej summit
# 2972         4 BHK Flat in Gwal Pahari     krrish provence estate
# 2973   4 BHK Flat in Sector 95 Gurgaon    sidhartha ncr one phase
#
#                  price price_per_sqft  \
# 25    Price on Request            NaN
# 1644  Price on Request            NaN
# 1972  Price on Request            NaN
# ...

# %%
df = df[df['price'] != 'Price on Request']

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
def treat_price(x):
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
df['price'] = df['price'].str.split(' ').apply(treat_price)

# %%
df.head(5)
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# price_per_sqft
df['price_per_sqft'].value_counts()
# Out:
# ₹ 10,000/sq.ft.     19
# ₹ 12,500/sq.ft.     16
# ₹ 8,000/sq.ft.      16
# ₹ 6,666/sq.ft.      13
# ₹ 5,000/sq.ft.      13
# ₹ 8,333/sq.ft.      12
# ₹ 7,500/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 7,000/sq.ft.       8
# ₹ 12,000/sq.ft.      8
# ₹ 9,000/sq.ft.       7
# ₹ 6,578/sq.ft.       6
# ₹ 8,928/sq.ft.       6
# ₹ 5,500/sq.ft.       6
# ₹ 11,111/sq.ft.      6
# ₹ 9,230/sq.ft.       6
# ₹ 8,888/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 11,428/sq.ft.      5
# ₹ 16,000/sq.ft.      5
# ₹ 5,600/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 8,205/sq.ft.       5
# ₹ 7,142/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 4,444/sq.ft.       5
# ₹ 5,556/sq.ft.       5
# ₹ 7,641/sq.ft.       5
# ₹ 8,571/sq.ft.       5
# ₹ 7,692/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 6,500/sq.ft.       5
# ₹ 5,384/sq.ft.       5
# ₹ 4,666/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 9,210/sq.ft.       4
# ₹ 8,139/sq.ft.       4
# ₹ 10,383/sq.ft.      4
# ₹ 8,484/sq.ft.       4
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# bedrooms
df['bedRoom'].value_counts()
# Out:
# 3 Bedrooms    1437
# 2 Bedrooms     944
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# Name: bedRoom, dtype: int64

# %%
df[df['bedRoom'].isnull()]
# Out:
#                                   property_name                       society  \
# 2849           2 BHK Flat in Sector 107 Gurgaon       signature global solera
# 2850            4 BHK Flat in Sector 53 Gurgaon                tulip monsella
# 2851              2 BHK Flat in New Palam Vihar                       my home
# 2852                        2 BHK Flat in Sohna        breez global hill view
# 2922           3 BHK Flat in Sector 99A Gurgaon      pareena coban residences
# 2923         1 BHK Flat in Golf Course Ext Road  ikon tower baani city centre
# 2924            2 BHK Flat in Sector 89 Gurgaon                   greenopolis
# 2926  4 BHK Flat in C Block Sushant Lok Phase 1                 maple heights
# 2927            2 BHK Flat in Sector 99 Gurgaon                assotech blith
#
#       price  price_per_sqft areaWithType bedRoom bathroom balcony  \
# 2849    NaN             NaN          NaN     NaN      NaN     NaN
# ...

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# bathroom
df['bathroom'].value_counts()
# Out:
# 2 Bathrooms    1044
# 3 Bathrooms     989
# 4 Bathrooms     636
# 5 Bathrooms     169
# 1 Bathroom      112
# 6 Bathrooms      42
# 7 Bathrooms       5
# Name: bathroom, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#        balcony additionalRoom                              address  \
# ...

# %%
# balcony
df['balcony'].value_counts()
# Out:
# 3 Balconies     974
# 3+ Balconies    862
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: balcony, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
# additionalRoom
df['additionalRoom'].value_counts()
# Out:
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Servant Room,Study Room                            8
# Study Room,Pooja Room                              8
# Study Room,Servant Room,Store Room                 7
# ...

# %%
df['additionalRoom'].value_counts().shape
# Out:
# (49,)

# %%
df['additionalRoom'].isnull().sum()
# Out:
# 1305

# %%
df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
# floor num
df['floorNum']
# Out:
# 0              4th   of 4 Floors
# 1              1st   of 3 Floors
# 2            12nd   of 14 Floors
# 3              2nd   of 4 Floors
# 4              5th   of 8 Floors
# 5              3rd   of 3 Floors
# 6             5th   of 25 Floors
# 7            14th   of 27 Floors
# 8              2nd   of 3 Floors
# 9            31st   of 40 Floors
# 10             1st   of 4 Floors
# 11            4th   of 13 Floors
# 12            4th   of 15 Floors
# 13            3rd   of 20 Floors
# 14           13rd   of 13 Floors
# 15           25th   of 25 Floors
# 16            Ground of 1 Floors
# 17           Ground of 14 Floors
# 18           11st   of 14 Floors
# 19           12nd   of 13 Floors
# 20             4th   of 4 Floors
# 21           11st   of 22 Floors
# 22             4th   of 4 Floors
# 23           Ground of 14 Floors
# 24           10th   of 25 Floors
# 26             3rd   of 3 Floors
# 27           20th   of 20 Floors
# 28            5th   of 17 Floors
# ...

# %%
df['floorNum'].isnull().sum()
# Out:
# 2

# %%
df[df['floorNum'].isnull()]
# Out:
#                                 property_name             society  price  \
# 181   3 BHK Flat in Dwarka Expressway Gurgaon  experion heartsong   1.08
# 2766          2 BHK Flat in Sector 78 Gurgaon                 nan   0.60
#
#       price_per_sqft                        areaWithType  bedRoom  bathroom  \
# 181           6150.0  Built Up area: 1758 (163.32 sq.m.)        3         3
# 2766          3692.0  Built Up area: 1625 (150.97 sq.m.)        2         2
#
#      balcony additionalRoom  \
# 181        0  not available
# 2766       0  not available
#
#                                                 address floorNum facing  \
# 181   604, Tower B-3, 6th Floor,Sector 108, Dwarka E...      NaN    NaN
# 2766       Gurgaon, Sector 78 Gurgaon, Gurgaon, Haryana      NaN    NaN
#
#            agePossession nearbyLocations  \
# 181   Under Construction             NaN
# 2766  Under Construction             NaN
#
# ...

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# ...

# %%
# facing
df['facing'].value_counts()
# Out:
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: facing, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# 874

# %%
df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# NA            874
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: facing, dtype: int64

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.insert(loc=1,column='property_type',value='flat')

# %%
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 3016
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2997 non-null   object
#  1   property_type    2997 non-null   object
#  2   society          2997 non-null   object
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     2997 non-null   object
#  7   bedRoom          2997 non-null   int32
#  8   bathroom         2997 non-null   int32
#  9   balcony          2997 non-null   object
#  10  additionalRoom   2997 non-null   object
#  11  address          2991 non-null   object
#  12  floorNum         2995 non-null   object
#  13  facing           2997 non-null   object
#  14  agePossession    2996 non-null   object
#  15  nearbyLocations  2906 non-null   object
# ...

# %%
df.shape
# Out:
# (2997, 20)

# %%
df1 = pd.read_csv('houses.csv')
df1.sample(5)
# Out:
#                                       property_name  \
# 1002        4 Bedroom House for sale in DLF Phase 1
# 190       4 Bedroom House for sale in Shivaji Nagar
# 890         4 Bedroom House for sale in DLF Phase 1
# 919   5 Bedroom House for sale in Sector 31 Gurgaon
# 979   5 Bedroom House for sale in Sector 48 Gurgaon
#
#                                                    link          society  \
# 1002  https://www.99acres.com/4-bhk-bedroom-independ...              NaN
# 190   https://www.99acres.com/4-bhk-bedroom-independ...   Not Applicable
# 890   https://www.99acres.com/4-bhk-bedroom-independ...   DLF City Plots
# 919   https://www.99acres.com/5-bhk-bedroom-independ...              NaN
# 979   https://www.99acres.com/5-bhk-bedroom-independ...  Eldeco Mansionz
#
#            price             rate                   area  \
# 1002  4.45 Crore  ₹ 35,185/sq.ft.  (125 sq.m.) Plot Area
# 190    2.2 Crore  ₹ 12,222/sq.ft.  (167 sq.m.) Plot Area
# ...

# %%
# shape
df1.shape
# Out:
# (1044, 21)

# %%
# info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1044 non-null   object
#  1   link             1044 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             1005 non-null   object
#  5   area             1044 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
# check for duplicates
df1.duplicated().sum()
# Out:
# 13

# %%
d1f = df1.drop_duplicates()

# %%
df1.shape
# Out:
# (1044, 21)

# %%
# check for missing values
df1.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            591
# price               76
# rate                39
# area                 0
# areaWithType        57
# bedRoom             57
# bathroom            57
# balcony             57
# additionalRoom     455
# address             13
# noOfFloor           77
# facing             370
# agePossession       57
# nearbyLocations    131
# description          8
# furnishDetails     301
# features           370
# rating             137
# property_id          8
# dtype: int64

# %%
# Columns to drop -> property_name, link, property_id
df1.drop(columns=['link','property_id'], inplace=True)

# %%
df1.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# rename columns
df1.rename(columns={'rate':'price_per_sqft'},inplace=True)
df1.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# society
df1['society'].value_counts()
# Out:
# Vipul Tatvam Villa                                   26
# Emaar MGF Marbella                                   26
# International City by SOBHA Phase 2                  26
# International City by Sobha Phase 1                  23
# Unitech Uniworld Resorts                             13
# DLF City Plots                                       11
# DLF City Plots Phase 2                               11
# Unitech Espace                                       11
# Bptp Visionnaire                                      9
# Eldeco Mansionz                                       9
# Uppal Southend4.0 ★                                   8
# Not Applicable                                        7
# Sushant Lok 1 Builder Floors                          6
# Ansals Palam Vihar                                    6
# Experion Windchants3.8 ★                              6
# DLF City Phase 1                                      5
# Vatika India Next4.1 ★                                4
# ...

# %%
df1['society'].value_counts().shape
# Out:
# (185,)

# %%
import re
df1['society'] = df1['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df1['society'].value_counts().shape
# Out:
# (183,)

# %%
df1['society'] = df1['society'].str.replace('nan','independent')

# %%
df1.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# price
df1['price'].value_counts()
# Out:
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 50 Lac              13
# 5 Crore             13
# 8 Crore             13
# 4.5 Crore           13
# 75 Lac              13
# 70 Lac              13
# 85 Lac              12
# 8.5 Crore           12
# 2.5 Crore           12
# 7 Crore             12
# 4 Crore             11
# 1.5 Crore           11
# 45 Lac              10
# 9 Crore             10
# Price on Request    10
# 2.25 Crore          10
# 60 Lac              10
# 90 Lac              10
# 10 Crore            10
# 1.1 Crore            9
# 80 Lac               9
# 1.7 Crore            9
# 9.5 Crore            9
# 2 Crore              9
# 12 Crore             9
# 11 Crore             8
# 1 Crore              8
# 1.6 Crore            8
# 6.75 Crore           8
# 4.6 Crore            8
# 3.75 Crore           8
# 1.35 Crore           7
# 1.3 Crore            7
# 65 Lac               7
# 12.5 Crore           7
# 55 Lac               7
# ...

# %%
df1 = df1[df1['price'] != 'Price on Request']

# %%
df1.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
def treat_price(x):
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
df1['price'] = df1['price'].str.split(' ').apply(treat_price)

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#      price_per_sqft                   area                 areaWithType  \
# 0   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
# price_per_sqft
df1['price_per_sqft'].value_counts()
# Out:
# ₹ 22,222/sq.ft.     14
# ₹ 11,111/sq.ft.     11
# ₹ 33,333/sq.ft.     11
# ₹ 10,000/sq.ft.     10
# ₹ 26,235/sq.ft.      6
# ₹ 26,667/sq.ft.      6
# ₹ 31,481/sq.ft.      6
# ₹ 30,556/sq.ft.      6
# ₹ 37,037/sq.ft.      6
# ₹ 13,333/sq.ft.      6
# ₹ 23,148/sq.ft.      5
# ₹ 23,333/sq.ft.      5
# ₹ 5,000/sq.ft.       5
# ₹ 9,444/sq.ft.       5
# ₹ 8,889/sq.ft.       5
# ₹ 11,100/sq.ft.      5
# ₹ 8,000/sq.ft.       5
# ₹ 21,605/sq.ft.      4
# ₹ 6,944/sq.ft.       4
# ₹ 24,691/sq.ft.      4
# ₹ 25,000/sq.ft.      4
# ₹ 18,889/sq.ft.      4
# ₹ 9,722/sq.ft.       4
# ₹ 32,407/sq.ft.      4
# ₹ 34,722/sq.ft.      4
# ₹ 7,058/sq.ft.       4
# ₹ 35,000/sq.ft.      4
# ₹ 27,778/sq.ft.      4
# ₹ 12,000/sq.ft.      3
# ₹ 33,951/sq.ft.      3
# ₹ 13,889/sq.ft.      3
# ₹ 45,833/sq.ft.      3
# ₹ 14,815/sq.ft.      3
# ₹ 36,111/sq.ft.      3
# ₹ 60,000/sq.ft.      3
# ₹ 17,284/sq.ft.      3
# ₹ 8,444/sq.ft.       3
# ₹ 15,555/sq.ft.      3
# ₹ 8,333/sq.ft.       3
# ₹ 32,222/sq.ft.      3
# ...

# %%
df1['price_per_sqft'] = df1['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
# bedrooms
df1['bedRoom'].value_counts()
# Out:
# 4 Bedrooms     239
# 5 Bedrooms     195
# 3 Bedrooms     148
# 2 Bedrooms      88
# 6 Bedrooms      82
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      34
# 7 Bedrooms      31
# 12 Bedrooms     29
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 21 Bedrooms      1
# 36 Bedrooms      1
# 14 Bedrooms      1
# 34 Bedrooms      1
# 20 Bedrooms      1
# Name: bedRoom, dtype: int64

# %%
df1[df1['bedRoom'].isnull()]
# Out:
#                                          property_name  \
# 62      5 Bedroom House for sale in Sector 109 Gurgaon
# 63      4 Bedroom House for sale in Sector 109 Gurgaon
# 66       5 Bedroom House for sale in Sector 66 Gurgaon
# 67       4 Bedroom House for sale in Sector 66 Gurgaon
# 68      5 Bedroom House for sale in Sector 109 Gurgaon
# 69      4 Bedroom House for sale in Sector 109 Gurgaon
# 70      3 Bedroom House for sale in Sector 109 Gurgaon
# 71      4 Bedroom House for sale in Sector 112 Gurgaon
# 72       4 Bedroom House for sale in Sector 66 Gurgaon
# 73       5 Bedroom House for sale in Sector 66 Gurgaon
# 74       4 Bedroom House for sale in Sector 66 Gurgaon
# 75       3 Bedroom House for sale in Sector 73 Gurgaon
# 76      5 Bedroom House for sale in Sector 109 Gurgaon
# 77      4 Bedroom House for sale in Sector 109 Gurgaon
# 78      3 Bedroom House for sale in Sector 109 Gurgaon
# 81       5 Bedroom House for sale in Sector 66 Gurgaon
# ...

# %%
df1 = df1[~df1['bedRoom'].isnull()]

# %%
df1.shape
# Out:
# (977, 19)

# %%
df1['bedRoom'] = df1['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom      bathroom       balcony                      additionalRoom  \
# ...

# %%
# bathroom
df1['bathroom'].value_counts()
# Out:
# 4 Bathrooms     233
# 3 Bathrooms     166
# 5 Bathrooms     139
# 2 Bathrooms     114
# 6 Bathrooms      85
# 1 Bathroom       65
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      29
# 12 Bathrooms     23
# 10 Bathrooms     11
# 16 Bathrooms      8
# 11 Bathrooms      4
# 18 Bathrooms      4
# 13 Bathrooms      4
# 20 Bathrooms      3
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 34 Bathrooms      1
# 36 Bathrooms      1
# Name: bathroom, dtype: int64

# %%
df1['bathroom'].isnull().sum()
# Out:
# 0

# %%
 df1['bathroom'] = df1['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom       balcony                      additionalRoom  \
# ...

# %%
# balcony
df1['balcony'].value_counts()
# Out:
# 3+ Balconies    373
# 2 Balconies     223
# 3 Balconies     161
# No Balcony      115
# 1 Balcony       105
# Name: balcony, dtype: int64

# %%
df1['balcony'].isnull().sum()
# Out:
# 0

# %%
df1['balcony'] = df1['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# ...

# %%
# additionalRoom
df1['additionalRoom'].value_counts()
# Out:
# Servant Room                                     82
# Pooja Room,Study Room,Servant Room,Store Room    63
# Others                                           59
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               34
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room,Servant Room                          19
# Study Room                                       19
# Servant Room,Store Room                          15
# Pooja Room,Store Room                            11
# Pooja Room,Study Room                            11
# Pooja Room,Others                                11
# Pooja Room,Store Room,Study Room,Servant Room     9
# Servant Room,Others                               8
# Servant Room,Pooja Room                           8
# Servant Room,Pooja Room,Store Room                7
# ...

# %%
df1['additionalRoom'].fillna('not available',inplace=True)

# %%
df1['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
# floors
df1['noOfFloor'].value_counts()
# Out:
# 3 Floors     309
# 2 Floors     294
# 1 Floors     181
# 4 Floors     137
# 5 Floors       9
# 0 Floors       6
# 6 Floors       3
# 14 Floors      3
# 11 Floors      2
# 12 Floors      2
# 10 Floors      2
# 51 Floors      1
# 41 Floors      1
# 27 Floors      1
# 02 Floors      1
# 21 Floors      1
# 16 Floors      1
# 33 Floors      1
# 13 Floors      1
# 20 Floors      1
# Name: noOfFloor, dtype: int64

# %%
df1['noOfFloor'].isnull().sum()
# Out:
# 20

# %%
df1['noOfFloor'] = df1['noOfFloor'].str.split(' ').str.get(0)

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
df1.rename(columns={'noOfFloor':'floorNum'},inplace=True)

# %%
df1.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
df1['facing'].fillna('NA',inplace=True)

# %%
df1['area'] = round((df1['price']*10000000)/df1['price_per_sqft'])

# %%
df1.insert(loc=1,column='property_type',value='house')

# %%
df1.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1       independent   5.70        105751.0   539.0
# 2       independent   2.10         38251.0   549.0
# 3       independent   5.00         43066.0  1161.0
# 4       independent   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+  not available
# 1   Plot area 539(50.07 sq.m.)        5         4       2  not available
# ...

# %%
df1.shape
# Out:
# (977, 20)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 977 entries, 0 to 1043
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    977 non-null    object
#  1   property_type    977 non-null    object
#  2   society          977 non-null    object
#  3   price            958 non-null    float64
#  4   price_per_sqft   958 non-null    float64
#  5   area             958 non-null    float64
#  6   areaWithType     977 non-null    object
#  7   bedRoom          977 non-null    int32
#  8   bathroom         977 non-null    int32
#  9   balcony          977 non-null    object
#  10  additionalRoom   976 non-null    object
#  11  address          972 non-null    object
#  12  floorNum         957 non-null    object
#  13  facing           977 non-null    object
#  14  agePossession    977 non-null    object
#  15  nearbyLocations  861 non-null    object
# ...

# %%
df2 = pd.concat([df,df1],ignore_index=True)

# %%
df2.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
df2.shape
# Out:
# (4951, 20)

# %%
df2.to_csv('gurgaon_properties.csv',index=False)
